# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(0,100)

y = x*(x-1)/2 # number of edges in a complete graph



plt.plot(x,y)

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(0,100)

y = x*(x-1)/2 # number of edges in a complete graph

plt.plot(x,y)
